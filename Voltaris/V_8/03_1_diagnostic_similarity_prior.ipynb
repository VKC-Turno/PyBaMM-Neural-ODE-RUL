# %% [markdown]
# # V8 · Stage 3.1 — Diagnostic-similarity weighted prior over anchors
#
# **Roadmap reference**: [`paper/research_roadmap.md`](../../paper/research_roadmap.md) · Stage 3 · Task 3.1
# **Strategy plan**: [`pybamm_research_strengthening_plan.md`](../../pybamm_research_strengthening_plan.md)
#
# ## Acceptance criterion
# θ_prior = Σ w_i θ_i with w_i ∝ exp(-d/τ) over anchors using capacity, DCIR, partial voltage curve, GITT diffusivity. Supplier ID auxiliary only.
#
# ## Expected outputs
# - `Voltaris/Data_Exploration/phase3_v8_validate.py — new theta_prior_from_features()`
# - `outputs/results/weighted_prior_eval.json`
#
# ## Status
# `pending` — no results yet.  Update to `running` / `passed` / `failed` in the last cell of this notebook when execution completes.

# %% [markdown]
# ## 1. Setup

# %%
# Standard imports for a V8 task notebook.
import sys, json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path("/home/hj/Desktop/PINNs")
sys.path.insert(0, str(PROJECT_ROOT / "Voltaris" / "Data_Exploration"))

# Reproducibility — see project convention: seeds are per-phase.
SEED = 456   # v8 uses phase3's canonical seed unless overridden per task
np.random.seed(SEED)

# %% [markdown]
# ## 2. Inputs

# %%
# Load the inputs required by this task.
# Fill in when the task is executed.
raise NotImplementedError("Task not started. See acceptance criterion above.")

# %% [markdown]
# ## 3. Method

# %%
# Analytical / training / evaluation code goes here.
# Keep the output artifacts consistent with the "Expected outputs" list above.

# %% [markdown]
# ## 4. Results
#
# Every result cell below should print or display something reviewable —
# tables, plots, RMSE numbers, calibration curves, etc.

# %%
# Emit the artifact(s) listed in the header + a human-readable summary.

# %% [markdown]
# ## 5. Verdict marker (update when done)
#
# Exactly ONE of the three:
#
# - [ ] **PASS** — acceptance criterion fully met.
# - [ ] **PASS WITH LIMITATIONS** — criterion met with a named caveat (state it in Notes).
# - [ ] **FAIL — BLOCKS DOWNSTREAM CLAIM** — criterion not met; must be resolved before dependent tasks.
#
# **Downstream consequence if FAIL**: state which later notebooks or which
# claim in the eventual V8 abstract cannot proceed until this is resolved.
#
# - Overall verdict: `pending`
# - Result artifact(s) written: `no`
# - Notes: _(free text once run)_
